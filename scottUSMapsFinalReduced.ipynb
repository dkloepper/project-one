# %%
import os
import pandas as pd
import plotly as py
import plotly.figure_factory as ff

import numpy as np

#import the csv file of combined census and epa data
full_data = pd.read_csv ("census_and_epa.csv")

# %%
# calculate the percentage of the number of good days per row
full_data["Percent Good"] = (full_data["Good Days"] / full_data["Days with AQI"]) * 100
full_data
# Out:
#       Unnamed: 0  Unnamed: 0.1          State        County  Year  \
# 0              0             0        Alabama       Baldwin  2012
# 1              1             3        Alabama        DeKalb  2012
# 2              2             4        Alabama        Elmore  2012
# 3              3             5        Alabama        Etowah  2012
# 4              4             6        Alabama       Houston  2012
# 5              5             7        Alabama     Jefferson  2012
# 6              6             9        Alabama       Madison  2012
# 7              7            10        Alabama        Mobile  2012
# 8              8            11        Alabama    Montgomery  2012
# 9              9            12        Alabama        Morgan  2012
# 10            10            14        Alabama        Shelby  2012
# 11            11            15        Alabama     Talladega  2012
# 12            12            16        Alabama    Tuscaloosa  2012
# 13            13            25        Arizona        Apache  2012
# 14            14            26        Arizona       Cochise  2012
# 15            15            27        Arizona      Coconino  2012
# 16            16            30        Arizona      Maricopa  2012
# 17            17            31        Arizona        Mohave  2012
# 18            18            32        Arizona        Navajo  2012
# 19            19            33        Arizona          Pima  2012
# 20            20            34        Arizona         Pinal  2012
# 21            21            36        Arizona       Yavapai  2012
# 22            22            37        Arizona          Yuma  2012
# 23            23            42       Arkansas      Faulkner  2012
# 24            24            43       Arkansas       Garland  2012
# 25            25            49       Arkansas       Pulaski  2012
# 26            26            51       Arkansas    Washington  2012
# 27            27            52     California       Alameda  2012
# 28            28            55     California         Butte  2012
# 29            29            58     California  Contra Costa  2012
# ...          ...           ...            ...           ...   ...
# 3629        3629          6295     Washington       Spokane  2017
# 3630        3630          6297     Washington      Thurston  2017
# 3631        3631          6299     Washington       Whatcom  2017
# 3632        3632          6301     Washington        Yakima  2017
# 3633        3633          6302  West Virginia      Berkeley  2017
# 3634        3634          6304  West Virginia        Cabell  2017
# 3635        3635          6308  West Virginia      Harrison  2017
# 3636        3636          6309  West Virginia       Kanawha  2017
# 3637        3637          6314  West Virginia    Monongalia  2017
# 3638        3638          6317  West Virginia          Wood  2017
# 3639        3639          6319      Wisconsin         Brown  2017
# 3640        3640          6321      Wisconsin          Dane  2017
# 3641        3641          6322      Wisconsin         Dodge  2017
# 3642        3642          6324      Wisconsin    Eau Claire  2017
# 3643        3643          6325      Wisconsin   Fond du Lac  2017
# 3644        3644          6328      Wisconsin     Jefferson  2017
# 3645        3645          6329      Wisconsin       Kenosha  2017
# 3646        3646          6331      Wisconsin     La Crosse  2017
# 3647        3647          6332      Wisconsin     Manitowoc  2017
# 3648        3648          6333      Wisconsin      Marathon  2017
# 3649        3649          6334      Wisconsin     Milwaukee  2017
# 3650        3650          6336      Wisconsin     Outagamie  2017
# 3651        3651          6337      Wisconsin       Ozaukee  2017
# 3652        3652          6338      Wisconsin        Racine  2017
# 3653        3653          6339      Wisconsin          Rock  2017
# 3654        3654          6341      Wisconsin     Sheboygan  2017
# 3655        3655          6344      Wisconsin      Walworth  2017
# 3656        3656          6345      Wisconsin      Waukesha  2017
# 3657        3657          6352        Wyoming       Laramie  2017
# 3658        3658          6354        Wyoming       Natrona  2017
#
#       Days with AQI  Good Days  Moderate Days  \
# 0               284        226             56
# 1               361        282             74
# 2               245        212             33
# 3               277        229             48
# 4               284        238             46
# 5               366        148            198
# 6               338        242             82
# 7               284        229             52
# 8               280        211             68
# 9               283        218             59
# 10              283        213             64
# 11              116         82             34
# 12              283        255             28
# 13              354        351              3
# 14              360        208            143
# 15              366        238            113
# 16              366         46            252
# 17              240        235              4
# 18              366        245            114
# 19              366        183            174
# 20              366         49            234
# 21              283        206             68
# 22              366        233            107
# 23               60         48             12
# 24              122         87             35
# 25              366        147            202
# 26              366        261             88
# 27              366        262            100
# 28              366        170            165
# 29              366        292             70
# ...             ...        ...            ...
# 3629            365        263             86
# 3630            363        308             51
# 3631            365        243            106
# 3632            365        233            103
# 3633            285        253             32
# 3634            283        251             30
# 3635            122        111             11
# 3636            364        301             62
# 3637            362        336             26
# 3638            357        327             30
# 3639            364        323             41
# 3640            365        298             67
# 3641            365        314             50
# 3642            365        324             41
# 3643            236        216             20
# 3644            245        214             31
# 3645            360        272             78
# 3646            360        311             49
# 3647            237        216             17
# 3648            237        223             14
# 3649            365        274             87
# 3650            365        299             57
# 3651            348        293             47
# 3652            230        176             43
# 3653            234        203             31
# 3654            245        192             40
# 3655            243        219             24
# 3656            359        287             72
# 3657            365        281             81
# 3658            365        297             66
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days      ...       \
# 0                                       2               0      ...
# 1                                       5               0      ...
# 2                                       0               0      ...
# 3                                       0               0      ...
# 4                                       0               0      ...
# 5                                      16               4      ...
# 6                                      14               0      ...
# 7                                       3               0      ...
# 8                                       1               0      ...
# 9                                       6               0      ...
# 10                                      6               0      ...
# 11                                      0               0      ...
# 12                                      0               0      ...
# 13                                      0               0      ...
# 14                                      9               0      ...
# 15                                     15               0      ...
# 16                                     61               6      ...
# 17                                      1               0      ...
# 18                                      7               0      ...
# 19                                      9               0      ...
# 20                                     69               7      ...
# 21                                      9               0      ...
# 22                                     24               2      ...
# 23                                      0               0      ...
# 24                                      0               0      ...
# 25                                     17               0      ...
# 26                                     16               1      ...
# 27                                      3               1      ...
# 28                                     23               8      ...
# 29                                      3               1      ...
# ...                                   ...             ...      ...
# 3629                                   10               3      ...
# 3630                                    2               2      ...
# 3631                                   13               3      ...
# 3632                                   21               5      ...
# 3633                                    0               0      ...
# 3634                                    2               0      ...
# 3635                                    0               0      ...
# 3636                                    1               0      ...
# 3637                                    0               0      ...
# 3638                                    0               0      ...
# 3639                                    0               0      ...
# 3640                                    0               0      ...
# 3641                                    1               0      ...
# 3642                                    0               0      ...
# 3643                                    0               0      ...
# 3644                                    0               0      ...
# 3645                                   10               0      ...
# 3646                                    0               0      ...
# 3647                                    4               0      ...
# 3648                                    0               0      ...
# 3649                                    4               0      ...
# 3650                                    9               0      ...
# 3651                                    8               0      ...
# 3652                                   11               0      ...
# 3653                                    0               0      ...
# 3654                                   13               0      ...
# 3655                                    0               0      ...
# 3656                                    0               0      ...
# 3657                                    1               2      ...
# 3658                                    2               0      ...
#
#       PctBelowPoverty Under 18  PctBelowPoverty 18 to 64  \
# 0                         20.2                      14.2
# 1                         20.4                      12.9
# 2                         19.9                      10.1
# 3                         32.4                      19.8
# 4                         28.8                      17.1
# 5                         28.0                      17.0
# 6                         15.9                      12.0
# 7                         30.5                      17.4
# 8                         30.5                      19.7
# 9                         21.9                      13.5
# 10                        13.1                       7.7
# 11                        42.1                      21.3
# 12                        26.2                      17.7
# 13                        40.9                      34.9
# 14                        26.4                      17.1
# 15                        34.5                      24.9
# 16                        25.5                      16.4
# 17                        33.7                      20.5
# 18                        38.4                      28.9
# 19                        29.2                      18.8
# 20                        23.8                      15.8
# 21                        20.6                      14.7
# 22                        30.4                      19.3
# 23                        12.7                      11.7
# 24                        32.7                      18.9
# 25                        29.0                      17.8
# 26                        25.1                      17.4
# 27                        17.4                      12.3
# 28                        26.7                      21.5
# 29                        14.9                       9.8
# ...                        ...                       ...
# 3629                      16.7                      15.0
# 3630                      12.6                      11.6
# 3631                      11.1                      15.7
# 3632                      27.6                      15.1
# 3633                      17.7                      10.9
# 3634                      40.8                      30.8
# 3635                      22.2                      20.2
# 3636                      26.9                      18.9
# 3637                      10.7                      23.0
# 3638                      29.9                      18.1
# 3639                      13.5                       8.9
# 3640                       9.7                      13.4
# 3641                       8.9                       8.2
# 3642                      15.1                      18.4
# 3643                      12.3                       6.9
# 3644                      11.6                       7.7
# 3645                      17.0                      10.0
# 3646                       7.0                      15.6
# 3647                      13.9                       7.8
# 3648                      13.4                       9.5
# 3649                      25.8                      17.8
# 3650                       7.9                       7.2
# 3651                       5.8                       5.8
# 3652                      18.2                       8.0
# 3653                      18.7                      11.9
# 3654                       6.6                       7.8
# 3655                       9.1                      12.7
# 3656                       5.4                       4.1
# 3657                       9.5                      10.1
# 3658                      10.6                      11.4
#
#       PctBelowPoverty 65 and over  PctBelowPoverty Male  \
# 0                            30.5                   NaN
# 1                             NaN                   NaN
# 2                            19.0                   NaN
# 3                            27.8                   NaN
# 4                            38.8                   NaN
# 5                            28.4                   NaN
# 6                            22.9                   NaN
# 7                            34.2                   NaN
# 8                            28.2                   NaN
# 9                            33.8                   NaN
# 10                           17.1                   NaN
# 11                           42.5                   NaN
# 12                           29.1                   NaN
# 13                            NaN                  40.9
# 14                            NaN                   NaN
# 15                            NaN                  39.6
# 16                           28.5                  29.1
# 17                            NaN                   NaN
# 18                            NaN                  46.0
# 19                           19.8                  38.3
# 20                           10.4                  42.5
# 21                            NaN                  36.8
# 22                            NaN                   NaN
# 23                           21.3                   NaN
# 24                           40.8                   NaN
# 25                           30.7                   NaN
# 26                           33.2                   NaN
# 27                           25.2                  15.2
# 28                           34.9                   NaN
# 29                           23.1                   NaN
# ...                           ...                   ...
# 3629                          6.8                  13.9
# 3630                          5.3                  10.3
# 3631                          5.7                  11.1
# 3632                         10.0                  15.8
# 3633                          8.6                   9.5
# 3634                          9.3                  26.1
# 3635                          8.8                  15.5
# 3636                          9.6                  17.2
# 3637                          4.1                  16.0
# 3638                         13.7                  15.3
# 3639                          7.1                   8.1
# 3640                          6.7                  11.7
# 3641                          6.6                   6.8
# 3642                          7.1                  13.5
# 3643                          7.1                   6.6
# 3644                          9.2                   6.1
# 3645                          8.4                  10.4
# 3646                          6.2                  10.3
# 3647                          6.7                   5.3
# 3648                          9.7                   8.5
# 3649                         11.5                  17.2
# 3650                          5.1                   6.3
# 3651                          4.5                   5.5
# 3652                          7.0                   9.4
# 3653                          5.7                  10.3
# 3654                          6.1                   6.9
# 3655                          5.0                  10.1
# 3656                          6.2                   4.0
# 3657                          9.7                   9.7
# 3658                          9.1                   9.7
#
#       PctBelowPoverty Female  PctBelowPoverty 16 and Over  \
# 0                        NaN                         20.1
# 1                        NaN                         36.6
# 2                        NaN                         14.5
# 3                        NaN                         40.5
# 4                        NaN                         38.4
# 5                       12.5                         42.2
# 6                        NaN                         31.9
# 7                       13.8                         39.4
# 8                        NaN                         40.1
# 9                        NaN                         33.4
# 10                       NaN                         26.6
# 11                       NaN                         63.1
# 12                      19.2                         30.4
# 13                       NaN                         54.9
# 14                       NaN                         33.9
# 15                       NaN                         38.2
# 16                      13.9                         36.5
# 17                       NaN                         50.4
# 18                       NaN                         45.7
# 19                      17.9                         44.8
# 20                       NaN                         31.7
# 21                       NaN                         27.4
# 22                       NaN                         42.1
# 23                       NaN                         44.3
# 24                       NaN                         43.0
# 25                      12.1                         34.6
# 26                       NaN                         48.3
# 27                       8.9                         29.2
# 28                      38.9                         37.7
# 29                       8.7                         22.2
# ...                      ...                          ...
# 3629                    14.3                          8.4
# 3630                    11.1                          8.8
# 3631                    15.0                          9.8
# 3632                    20.4                          9.2
# 3633                    14.8                          5.1
# 3634                    31.2                         18.7
# 3635                    21.2                         10.4
# 3636                    20.0                          8.7
# 3637                    21.3                         14.7
# 3638                    23.9                          8.7
# 3639                    11.3                          5.5
# 3640                    11.8                          8.5
# 3641                     9.4                          5.2
# 3642                    18.2                         13.5
# 3643                     9.6                          3.6
# 3644                    11.4                          5.7
# 3645                    12.3                          7.5
# 3646                    14.3                          9.2
# 3647                    12.3                          5.1
# 3648                    12.3                          6.0
# 3649                    20.5                         10.2
# 3650                     7.8                          4.4
# 3651                     5.6                          3.7
# 3652                    11.1                          4.3
# 3653                    14.6                          6.8
# 3654                     7.5                          5.6
# 3655                    11.1                         10.0
# 3656                     5.5                          2.5
# 3657                    10.2                          6.6
# 3658                    12.1                          8.5
#
#       PctBelowPoverty 16 and Over Employed  State Code  County Code  \
# 0                                     22.8           1            3
# 1                                     31.7           1           49
# 2                                     11.8           1           51
# 3                                     41.0           1           55
# 4                                     31.9           1           69
# 5                                     41.5           1           73
# 6                                     26.9           1           89
# 7                                     27.3           1           97
# 8                                     31.7           1          101
# 9                                     29.8           1          103
# 10                                    20.4           1          117
# 11                                    66.8           1          121
# 12                                    30.2           1          125
# 13                                    54.4           4            1
# 14                                    31.5           4            3
# 15                                    32.3           4            5
# 16                                    34.8           4           13
# 17                                    50.6           4           15
# 18                                    43.2           4           17
# 19                                    40.9           4           19
# 20                                    38.2           4           21
# 21                                    29.9           4           25
# 22                                    35.4           4           27
# 23                                    45.9           5           45
# 24                                    40.0           5           51
# 25                                    30.3           5          119
# 26                                    51.1           5          143
# 27                                    25.9           6            1
# 28                                    31.8           6            7
# 29                                    21.0           6           13
# ...                                    ...         ...          ...
# 3629                                   7.0          53           63
# 3630                                   7.4          53           67
# 3631                                   9.4          53           73
# 3632                                   8.0          53           77
# 3633                                   4.0          54            3
# 3634                                  18.0          54           11
# 3635                                   8.7          54           33
# 3636                                   6.3          54           39
# 3637                                  12.4          54           61
# 3638                                   6.6          54          107
# 3639                                   4.7          55            9
# 3640                                   7.9          55           25
# 3641                                   3.1          55           27
# 3642                                  12.7          55           35
# 3643                                   2.9          55           39
# 3644                                   4.5          55           55
# 3645                                   6.3          55           59
# 3646                                   8.6          55           63
# 3647                                   4.6          55           71
# 3648                                   4.3          55           73
# 3649                                   8.6          55           79
# 3650                                   3.6          55           87
# 3651                                   3.4          55           89
# 3652                                   3.4          55          101
# 3653                                   5.7          55          105
# 3654                                   5.3          55          117
# 3655                                   9.4          55          127
# 3656                                   2.4          55          133
# 3657                                   4.0          56           21
# 3658                                   6.0          56           25
#
#       Percent Good
# 0        79.577465
# 1        78.116343
# 2        86.530612
# 3        82.671480
# 4        83.802817
# 5        40.437158
# 6        71.597633
# 7        80.633803
# 8        75.357143
# 9        77.031802
# 10       75.265018
# 11       70.689655
# 12       90.106007
# 13       99.152542
# 14       57.777778
# 15       65.027322
# 16       12.568306
# 17       97.916667
# 18       66.939891
# 19       50.000000
# 20       13.387978
# 21       72.791519
# 22       63.661202
# 23       80.000000
# 24       71.311475
# 25       40.163934
# 26       71.311475
# 27       71.584699
# 28       46.448087
# 29       79.781421
# ...            ...
# 3629     72.054795
# 3630     84.848485
# 3631     66.575342
# 3632     63.835616
# 3633     88.771930
# 3634     88.692580
# 3635     90.983607
# 3636     82.692308
# 3637     92.817680
# 3638     91.596639
# 3639     88.736264
# 3640     81.643836
# 3641     86.027397
# 3642     88.767123
# 3643     91.525424
# 3644     87.346939
# 3645     75.555556
# 3646     86.388889
# 3647     91.139241
# 3648     94.092827
# 3649     75.068493
# 3650     81.917808
# 3651     84.195402
# 3652     76.521739
# 3653     86.752137
# 3654     78.367347
# 3655     90.123457
# 3656     79.944290
# 3657     76.986301
# 3658     81.369863
#
# [3659 rows x 49 columns]

# %%
#make state code a string and two digits by adding a zero in front of the codes that have only one digit
full_data['FIPSstate'] = full_data['State Code'].astype(str).str.zfill(2)

#make country code a string and three digits by adding zeroes in front of the codes that have less than three
full_data["FIPScnty"] = full_data["County Code"].astype(str).str.zfill(3)

#combine new FIPSstate and FIPScnty codes to make the FIPS code to fill in state/county info on a map
full_data["FIPS"] = full_data["FIPSstate"] + full_data["FIPScnty"]

# %%
full_data
# Out:
#       Unnamed: 0  Unnamed: 0.1          State        County  Year  \
# 0              0             0        Alabama       Baldwin  2012
# 1              1             3        Alabama        DeKalb  2012
# 2              2             4        Alabama        Elmore  2012
# 3              3             5        Alabama        Etowah  2012
# 4              4             6        Alabama       Houston  2012
# 5              5             7        Alabama     Jefferson  2012
# 6              6             9        Alabama       Madison  2012
# 7              7            10        Alabama        Mobile  2012
# 8              8            11        Alabama    Montgomery  2012
# 9              9            12        Alabama        Morgan  2012
# 10            10            14        Alabama        Shelby  2012
# 11            11            15        Alabama     Talladega  2012
# 12            12            16        Alabama    Tuscaloosa  2012
# 13            13            25        Arizona        Apache  2012
# 14            14            26        Arizona       Cochise  2012
# 15            15            27        Arizona      Coconino  2012
# 16            16            30        Arizona      Maricopa  2012
# 17            17            31        Arizona        Mohave  2012
# 18            18            32        Arizona        Navajo  2012
# 19            19            33        Arizona          Pima  2012
# 20            20            34        Arizona         Pinal  2012
# 21            21            36        Arizona       Yavapai  2012
# 22            22            37        Arizona          Yuma  2012
# 23            23            42       Arkansas      Faulkner  2012
# 24            24            43       Arkansas       Garland  2012
# 25            25            49       Arkansas       Pulaski  2012
# 26            26            51       Arkansas    Washington  2012
# 27            27            52     California       Alameda  2012
# 28            28            55     California         Butte  2012
# 29            29            58     California  Contra Costa  2012
# ...          ...           ...            ...           ...   ...
# 3629        3629          6295     Washington       Spokane  2017
# 3630        3630          6297     Washington      Thurston  2017
# 3631        3631          6299     Washington       Whatcom  2017
# 3632        3632          6301     Washington        Yakima  2017
# 3633        3633          6302  West Virginia      Berkeley  2017
# 3634        3634          6304  West Virginia        Cabell  2017
# 3635        3635          6308  West Virginia      Harrison  2017
# 3636        3636          6309  West Virginia       Kanawha  2017
# 3637        3637          6314  West Virginia    Monongalia  2017
# 3638        3638          6317  West Virginia          Wood  2017
# 3639        3639          6319      Wisconsin         Brown  2017
# 3640        3640          6321      Wisconsin          Dane  2017
# 3641        3641          6322      Wisconsin         Dodge  2017
# 3642        3642          6324      Wisconsin    Eau Claire  2017
# 3643        3643          6325      Wisconsin   Fond du Lac  2017
# 3644        3644          6328      Wisconsin     Jefferson  2017
# 3645        3645          6329      Wisconsin       Kenosha  2017
# 3646        3646          6331      Wisconsin     La Crosse  2017
# 3647        3647          6332      Wisconsin     Manitowoc  2017
# 3648        3648          6333      Wisconsin      Marathon  2017
# 3649        3649          6334      Wisconsin     Milwaukee  2017
# 3650        3650          6336      Wisconsin     Outagamie  2017
# 3651        3651          6337      Wisconsin       Ozaukee  2017
# 3652        3652          6338      Wisconsin        Racine  2017
# 3653        3653          6339      Wisconsin          Rock  2017
# 3654        3654          6341      Wisconsin     Sheboygan  2017
# 3655        3655          6344      Wisconsin      Walworth  2017
# 3656        3656          6345      Wisconsin      Waukesha  2017
# 3657        3657          6352        Wyoming       Laramie  2017
# 3658        3658          6354        Wyoming       Natrona  2017
#
#       Days with AQI  Good Days  Moderate Days  \
# 0               284        226             56
# 1               361        282             74
# 2               245        212             33
# 3               277        229             48
# 4               284        238             46
# 5               366        148            198
# 6               338        242             82
# 7               284        229             52
# 8               280        211             68
# 9               283        218             59
# 10              283        213             64
# 11              116         82             34
# 12              283        255             28
# 13              354        351              3
# 14              360        208            143
# 15              366        238            113
# 16              366         46            252
# 17              240        235              4
# 18              366        245            114
# 19              366        183            174
# 20              366         49            234
# 21              283        206             68
# 22              366        233            107
# 23               60         48             12
# 24              122         87             35
# 25              366        147            202
# 26              366        261             88
# 27              366        262            100
# 28              366        170            165
# 29              366        292             70
# ...             ...        ...            ...
# 3629            365        263             86
# 3630            363        308             51
# 3631            365        243            106
# 3632            365        233            103
# 3633            285        253             32
# 3634            283        251             30
# 3635            122        111             11
# 3636            364        301             62
# 3637            362        336             26
# 3638            357        327             30
# 3639            364        323             41
# 3640            365        298             67
# 3641            365        314             50
# 3642            365        324             41
# 3643            236        216             20
# 3644            245        214             31
# 3645            360        272             78
# 3646            360        311             49
# 3647            237        216             17
# 3648            237        223             14
# 3649            365        274             87
# 3650            365        299             57
# 3651            348        293             47
# 3652            230        176             43
# 3653            234        203             31
# 3654            245        192             40
# 3655            243        219             24
# 3656            359        287             72
# 3657            365        281             81
# 3658            365        297             66
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days  ...    \
# 0                                       2               0  ...
# 1                                       5               0  ...
# 2                                       0               0  ...
# 3                                       0               0  ...
# 4                                       0               0  ...
# 5                                      16               4  ...
# 6                                      14               0  ...
# 7                                       3               0  ...
# 8                                       1               0  ...
# 9                                       6               0  ...
# 10                                      6               0  ...
# 11                                      0               0  ...
# 12                                      0               0  ...
# 13                                      0               0  ...
# 14                                      9               0  ...
# 15                                     15               0  ...
# 16                                     61               6  ...
# 17                                      1               0  ...
# 18                                      7               0  ...
# 19                                      9               0  ...
# 20                                     69               7  ...
# 21                                      9               0  ...
# 22                                     24               2  ...
# 23                                      0               0  ...
# 24                                      0               0  ...
# 25                                     17               0  ...
# 26                                     16               1  ...
# 27                                      3               1  ...
# 28                                     23               8  ...
# 29                                      3               1  ...
# ...                                   ...             ...  ...
# 3629                                   10               3  ...
# 3630                                    2               2  ...
# 3631                                   13               3  ...
# 3632                                   21               5  ...
# 3633                                    0               0  ...
# 3634                                    2               0  ...
# 3635                                    0               0  ...
# 3636                                    1               0  ...
# 3637                                    0               0  ...
# 3638                                    0               0  ...
# 3639                                    0               0  ...
# 3640                                    0               0  ...
# 3641                                    1               0  ...
# 3642                                    0               0  ...
# 3643                                    0               0  ...
# 3644                                    0               0  ...
# 3645                                   10               0  ...
# 3646                                    0               0  ...
# 3647                                    4               0  ...
# 3648                                    0               0  ...
# 3649                                    4               0  ...
# 3650                                    9               0  ...
# 3651                                    8               0  ...
# 3652                                   11               0  ...
# 3653                                    0               0  ...
# 3654                                   13               0  ...
# 3655                                    0               0  ...
# 3656                                    0               0  ...
# 3657                                    1               2  ...
# 3658                                    2               0  ...
#
#       PctBelowPoverty Male  PctBelowPoverty Female  \
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
# 5                      NaN                    12.5
# 6                      NaN                     NaN
# 7                      NaN                    13.8
# 8                      NaN                     NaN
# 9                      NaN                     NaN
# 10                     NaN                     NaN
# 11                     NaN                     NaN
# 12                     NaN                    19.2
# 13                    40.9                     NaN
# 14                     NaN                     NaN
# 15                    39.6                     NaN
# 16                    29.1                    13.9
# 17                     NaN                     NaN
# 18                    46.0                     NaN
# 19                    38.3                    17.9
# 20                    42.5                     NaN
# 21                    36.8                     NaN
# 22                     NaN                     NaN
# 23                     NaN                     NaN
# 24                     NaN                     NaN
# 25                     NaN                    12.1
# 26                     NaN                     NaN
# 27                    15.2                     8.9
# 28                     NaN                    38.9
# 29                     NaN                     8.7
# ...                    ...                     ...
# 3629                  13.9                    14.3
# 3630                  10.3                    11.1
# 3631                  11.1                    15.0
# 3632                  15.8                    20.4
# 3633                   9.5                    14.8
# 3634                  26.1                    31.2
# 3635                  15.5                    21.2
# 3636                  17.2                    20.0
# 3637                  16.0                    21.3
# 3638                  15.3                    23.9
# 3639                   8.1                    11.3
# 3640                  11.7                    11.8
# 3641                   6.8                     9.4
# 3642                  13.5                    18.2
# 3643                   6.6                     9.6
# 3644                   6.1                    11.4
# 3645                  10.4                    12.3
# 3646                  10.3                    14.3
# 3647                   5.3                    12.3
# 3648                   8.5                    12.3
# 3649                  17.2                    20.5
# 3650                   6.3                     7.8
# 3651                   5.5                     5.6
# 3652                   9.4                    11.1
# 3653                  10.3                    14.6
# 3654                   6.9                     7.5
# 3655                  10.1                    11.1
# 3656                   4.0                     5.5
# 3657                   9.7                    10.2
# 3658                   9.7                    12.1
#
#       PctBelowPoverty 16 and Over  PctBelowPoverty 16 and Over Employed  \
# 0                            20.1                                  22.8
# 1                            36.6                                  31.7
# 2                            14.5                                  11.8
# 3                            40.5                                  41.0
# 4                            38.4                                  31.9
# 5                            42.2                                  41.5
# 6                            31.9                                  26.9
# 7                            39.4                                  27.3
# 8                            40.1                                  31.7
# 9                            33.4                                  29.8
# 10                           26.6                                  20.4
# 11                           63.1                                  66.8
# 12                           30.4                                  30.2
# 13                           54.9                                  54.4
# 14                           33.9                                  31.5
# 15                           38.2                                  32.3
# 16                           36.5                                  34.8
# 17                           50.4                                  50.6
# 18                           45.7                                  43.2
# 19                           44.8                                  40.9
# 20                           31.7                                  38.2
# 21                           27.4                                  29.9
# 22                           42.1                                  35.4
# 23                           44.3                                  45.9
# 24                           43.0                                  40.0
# 25                           34.6                                  30.3
# 26                           48.3                                  51.1
# 27                           29.2                                  25.9
# 28                           37.7                                  31.8
# 29                           22.2                                  21.0
# ...                           ...                                   ...
# 3629                          8.4                                   7.0
# 3630                          8.8                                   7.4
# 3631                          9.8                                   9.4
# 3632                          9.2                                   8.0
# 3633                          5.1                                   4.0
# 3634                         18.7                                  18.0
# 3635                         10.4                                   8.7
# 3636                          8.7                                   6.3
# 3637                         14.7                                  12.4
# 3638                          8.7                                   6.6
# 3639                          5.5                                   4.7
# 3640                          8.5                                   7.9
# 3641                          5.2                                   3.1
# 3642                         13.5                                  12.7
# 3643                          3.6                                   2.9
# 3644                          5.7                                   4.5
# 3645                          7.5                                   6.3
# 3646                          9.2                                   8.6
# 3647                          5.1                                   4.6
# 3648                          6.0                                   4.3
# 3649                         10.2                                   8.6
# 3650                          4.4                                   3.6
# 3651                          3.7                                   3.4
# 3652                          4.3                                   3.4
# 3653                          6.8                                   5.7
# 3654                          5.6                                   5.3
# 3655                         10.0                                   9.4
# 3656                          2.5                                   2.4
# 3657                          6.6                                   4.0
# 3658                          8.5                                   6.0
#
#       State Code  County Code  Percent Good  FIPSstate  FIPScnty   FIPS
# 0              1            3     79.577465         01       003  01003
# 1              1           49     78.116343         01       049  01049
# 2              1           51     86.530612         01       051  01051
# 3              1           55     82.671480         01       055  01055
# 4              1           69     83.802817         01       069  01069
# 5              1           73     40.437158         01       073  01073
# 6              1           89     71.597633         01       089  01089
# 7              1           97     80.633803         01       097  01097
# 8              1          101     75.357143         01       101  01101
# 9              1          103     77.031802         01       103  01103
# 10             1          117     75.265018         01       117  01117
# 11             1          121     70.689655         01       121  01121
# 12             1          125     90.106007         01       125  01125
# 13             4            1     99.152542         04       001  04001
# 14             4            3     57.777778         04       003  04003
# 15             4            5     65.027322         04       005  04005
# 16             4           13     12.568306         04       013  04013
# 17             4           15     97.916667         04       015  04015
# 18             4           17     66.939891         04       017  04017
# 19             4           19     50.000000         04       019  04019
# 20             4           21     13.387978         04       021  04021
# 21             4           25     72.791519         04       025  04025
# 22             4           27     63.661202         04       027  04027
# 23             5           45     80.000000         05       045  05045
# 24             5           51     71.311475         05       051  05051
# 25             5          119     40.163934         05       119  05119
# 26             5          143     71.311475         05       143  05143
# 27             6            1     71.584699         06       001  06001
# 28             6            7     46.448087         06       007  06007
# 29             6           13     79.781421         06       013  06013
# ...          ...          ...           ...        ...       ...    ...
# 3629          53           63     72.054795         53       063  53063
# 3630          53           67     84.848485         53       067  53067
# 3631          53           73     66.575342         53       073  53073
# 3632          53           77     63.835616         53       077  53077
# 3633          54            3     88.771930         54       003  54003
# 3634          54           11     88.692580         54       011  54011
# 3635          54           33     90.983607         54       033  54033
# 3636          54           39     82.692308         54       039  54039
# 3637          54           61     92.817680         54       061  54061
# 3638          54          107     91.596639         54       107  54107
# 3639          55            9     88.736264         55       009  55009
# 3640          55           25     81.643836         55       025  55025
# 3641          55           27     86.027397         55       027  55027
# 3642          55           35     88.767123         55       035  55035
# 3643          55           39     91.525424         55       039  55039
# 3644          55           55     87.346939         55       055  55055
# 3645          55           59     75.555556         55       059  55059
# 3646          55           63     86.388889         55       063  55063
# 3647          55           71     91.139241         55       071  55071
# 3648          55           73     94.092827         55       073  55073
# 3649          55           79     75.068493         55       079  55079
# 3650          55           87     81.917808         55       087  55087
# 3651          55           89     84.195402         55       089  55089
# 3652          55          101     76.521739         55       101  55101
# 3653          55          105     86.752137         55       105  55105
# 3654          55          117     78.367347         55       117  55117
# 3655          55          127     90.123457         55       127  55127
# 3656          55          133     79.944290         55       133  55133
# 3657          56           21     76.986301         56       021  56021
# 3658          56           25     81.369863         56       025  56025
#
# [3659 rows x 52 columns]

# %%
#create data frames to isolate data by year from 2012 - 2017

twenty_twelve = full_data.query("Year == 2012")
twenty_seventeen = full_data.query("Year == 2017")

# %%
# CREATE MAPS OF PERCENT GOOD AQI DAYS FOR EACH YEAR OF DATA

# create US map of 2012 percent good AQI days
colorscale=[ 'rgb(215,48,39)',
             'rgb(244,109,67)',
             'rgb(253,174,97)',
             'rgb(254,224,144)',
             'rgb(224,243,248)',
             'rgb(171,217,233)',
             'rgb(116,173,209)',
             'rgb(69,117,180)',
             ]

endpts = list(np.linspace(1, 100, len(colorscale) -1))
fips = twenty_twelve['FIPS'].tolist()
values = twenty_twelve['Percent Good'].tolist()

fig = ff.create_choropleth(
    fips=fips, values=values,
    binning_endpoints=endpts,
    colorscale=colorscale,
    show_state_data=True,
    show_hover=True, centroid_marker={'opacity': 0},
    asp=2.9, title='2012 -- % Good AQI Days',
    legend_title='Percent Range'
)
py.offline.plot(fig, filename='2012PctGoodAQIDays')
# Out:
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/plotly/offline/offline.py:654: UserWarning:
#
# Your filename `2012PctGoodAQIDays` didn't end with .html. Adding .html to the end of your file.
# 'file:///Users/xantar/Desktop/Project One/project-one/2012PctGoodAQIDays.html'

# %%
# create US map of 2017 percent good AQI days
colorscale = ['rgb(215,48,39)',
             'rgb(244,109,67)',
             'rgb(253,174,97)',
             'rgb(254,224,144)',
             'rgb(224,243,248)',
             'rgb(171,217,233)',
             'rgb(116,173,209)',
             'rgb(69,117,180)',
             ]
endpts = list(np.linspace(1, 100, len(colorscale) - 1))
fips = twenty_seventeen['FIPS'].tolist()
values = twenty_seventeen['Percent Good'].tolist()

fig = ff.create_choropleth(
    fips=fips, values=values,
    binning_endpoints=endpts,
    colorscale=colorscale,
    show_state_data=True,
    show_hover=True, centroid_marker={'opacity': 0},
    asp=2.9, title='2017 -- % Good AQI Days',
    legend_title='Percent Range'
)
py.offline.plot(fig, filename='2017PctGoodAQIDays')
# Out:
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/plotly/offline/offline.py:654: UserWarning:
#
# Your filename `2017PctGoodAQIDays` didn't end with .html. Adding .html to the end of your file.
# 'file:///Users/xantar/Desktop/Project One/project-one/2017PctGoodAQIDays.html'

# %% [markdown]
# CHARTING POVERTY DATA BY YEAR

# %%
# create percent below poverty level for ages 16 and up for each year
#2012 percent below poverty level ages 16 and up
colorscale = ["#f7fbff","#ebf3fb","#deebf7","#d2e3f3","#c6dbef","#b3d2e9","#9ecae1",
               "#85bcdb","#6baed6","#57a0ce","#4292c6","#3082be","#2171b5","#1361a9",
               "#08519c","#0b4083","#08306b"] 
endpts = list(np.linspace(1, 100, len(colorscale) - 1))
fips = twenty_twelve['FIPS'].tolist()
values = twenty_twelve['PctBelowPoverty 16 and Over'].tolist()

fig = ff.create_choropleth(
    fips=fips, values=values,
    binning_endpoints=endpts,
    colorscale=colorscale,
    show_state_data=True,
    show_hover=True, centroid_marker={'opacity': 0},
    asp=2.9, title='2012 -- % Below Poverty Level Age 16 and Over',
    legend_title='Percent Range'
)
py.offline.plot(fig, filename='2012PctBelowPoverty16up')
# Out:
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/plotly/offline/offline.py:654: UserWarning:
#
# Your filename `2012PctBelowPoverty16up` didn't end with .html. Adding .html to the end of your file.
# 'file:///Users/xantar/Desktop/Project One/project-one/2012PctBelowPoverty16up.html'

# %%
#2017 percent below poverty level ages 16 and up
colorscale = ["#f7fbff","#ebf3fb","#deebf7","#d2e3f3","#c6dbef","#b3d2e9","#9ecae1",
               "#85bcdb","#6baed6","#57a0ce","#4292c6","#3082be","#2171b5","#1361a9",
               "#08519c","#0b4083","#08306b"] 
endpts = list(np.linspace(1, 100, len(colorscale) - 1))
fips = twenty_seventeen['FIPS'].tolist()
values = twenty_seventeen['PctBelowPoverty 16 and Over'].tolist()

fig = ff.create_choropleth(
    fips=fips, values=values,
    binning_endpoints=endpts,
    colorscale=colorscale,
    show_state_data=True,
    show_hover=True, centroid_marker={'opacity': 0},
    asp=2.9, title='2017 -- % Below Poverty Level Age 16 and Over',
    legend_title='Percent Range'
)
py.offline.plot(fig, filename='2017PctBelowPoverty16up')
# Out:
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# /anaconda3/envs/pythondata/lib/python3.6/site-packages/plotly/offline/offline.py:654: UserWarning:
#
# Your filename `2017PctBelowPoverty16up` didn't end with .html. Adding .html to the end of your file.
# 'file:///Users/xantar/Desktop/Project One/project-one/2017PctBelowPoverty16up.html'
